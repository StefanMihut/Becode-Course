# %% [markdown]
# # Data cleaning using pandas
#
# In this notebook, you'll see how clean structured data using `pandas`. We are aware that you have already done an extensive review of pandas, and are now experts in data manipulation, so we'll keep it short.
#
# We are going to use a dataset about New York City Squirrels taken from [NYC Open Data](https://opendata.cityofnewyork.us/) which is a great resource for data sets.
# This dataset is quite small and this notebook will just be an overview of different stuff to look out for when cleaning data.

# %%
import pandas as pd
import numpy as np
filename="../../additional_resources/datasets/NYC Squirrels/data.csv"
df = pd.read_csv(filename)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Becode-Course\content\4.machine_learning\0.data_preprocessing\01.cleaning.ipynb Cell 2' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Becode-Course/content/4.machine_learning/0.data_preprocessing/01.cleaning.ipynb#ch0000001?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Becode-Course/content/4.machine_learning/0.data_preprocessing/01.cleaning.ipynb#ch0000001?line=2'>3</a> filename="../../additional_resources/datasets/NYC Squirrels/data.csv"
# ----> <a href='vscode-notebook-cell:/c%3A/Becode-Course/content/4.machine_learning/0.data_preprocessing/01.cleaning.ipynb#ch0000001?line=3'>4</a> df = pd.read_csv(filename)
#       <a href='vscode-notebook-cell:/c%3A/Becode-Course/content/4.machine_learning/0.data_preprocessing/01.cleaning.ipynb#ch0000001?line=4'>5</a> df.head()
#
# File c:\Users\dottz\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\dottz\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\dottz\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Users\dottz\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\dottz\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File c:\Users\dottz\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../additional_resources/datasets/NYC Squirrels/data.csv'

# %% [markdown]
# ## Things to check
# ### Missing values.
#
# There are different ways that a value can be missing. It can be just an empty string (`""`), or `NaN` (Not a Number).
# `np.nan`, `None` and `NaT` (for `datetime64` types) are standard missing value for Pandas.
#
# You can either delete the rows/attribute if there are too many missing, or replace them. I can't give you a certain threshold to delete or replace, it really depends on the variable, on the context, and what you are going to do with the data later on.
# In the same vein, there are many different ways to replace a value, and it will depend on the type of data you have. [[More info here]](https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html)
#
# Pandas provides `isnull()`, `isna()` functions to detect missing values. Both of them do the same thing.

# %%
print("There are {} rows of data".format(len(df)))
# Out:
# There are 3023 rows of data

# %% [markdown]
# We see that we have 3023 rows of data. Looking at the number of NaN values per column, one can confidently say that columns where we have > 1000 missing values are not worth keeping. The case can be made that, for certain scenarios, the columns `Highlight Fur Color` should be kept too, but here we are going to drop it because the column `Combination of Primary and Highlight Color` combines both.

# %% [markdown]
# This notebook is going to feature small code blocks that you'll have to complete.
#
# The first task is to count how many nan values there are per attribute.
# Hint: use `df.isnull()`

# %%
# Checking how many rows of each attribute are NaN
# Out:
# X                                                0
# Y                                                0
# Unique Squirrel ID                               0
# Hectare                                          0
# Shift                                            0
# Date                                             0
# Hectare Squirrel Number                          0
# Age                                            121
# Primary Fur Color                               55
# Highlight Fur Color                           1086
# Combination of Primary and Highlight Color       0
# Color notes                                   2841
# Location                                        64
# Above Ground Sighter Measurement               114
# Specific Location                             2547
# Running                                          0
# Chasing                                          0
# Climbing                                         0
# Eating                                           0
# Foraging                                         0
# Other Activities                              2586
# Kuks                                             0
# Quaas                                            0
# Moans                                            0
# Tail flags                                       0
# Tail twitches                                    0
# Approaches                                       0
# Indifferent                                      0
# Runs from                                        0
# Other Interactions                            2783
# Lat/Long                                         0
# dtype: int64

# %% [markdown]
# Now that we've identified all the columns that have NaN values, we would like to drop those with more than 1000 NaN values.
# Can you do that ?
# Hint: `df.drop()`
# Moreover, can you print the columns that were dropped, along with the number of missing values that they had ?

# %%
# Drop the columns that have more than 1000 missing values


        
# Print the columns that were dropped
# Out:
# Age                                  121
# Primary Fur Color                     55
# Highlight Fur Color                 1086
# Color notes                         2841
# Location                              64
# Above Ground Sighter Measurement     114
# Specific Location                   2547
# Other Activities                    2586
# Other Interactions                  2783
# dtype: int64

# %% [markdown]
# ### Attribute type
#
# Sometimes, an attribute does not have the correct type, e.g. integers are labeled as floats. So it is useful to check if it needs to be changed or not.
#
#
# Please print the dtypes of every attribute.

# %%
#Print dtype of every attribute
# Out:
# X                                             float64
# Y                                             float64
# Unique Squirrel ID                             object
# Hectare                                        object
# Shift                                          object
# Date                                            int64
# Hectare Squirrel Number                         int64
# Age                                            object
# Primary Fur Color                              object
# Combination of Primary and Highlight Color     object
# Location                                       object
# Above Ground Sighter Measurement               object
# Running                                          bool
# Chasing                                          bool
# Climbing                                         bool
# Eating                                           bool
# Foraging                                         bool
# Kuks                                             bool
# Quaas                                            bool
# Moans                                            bool
# Tail flags                                       bool
# Tail twitches                                    bool
# Approaches                                       bool
# Indifferent                                      bool
# Runs from                                        bool
# Lat/Long                                       object
# dtype: object

# %% [markdown]
# For example, for `Hectare`, one could think that the variable is just the size of the plot of land. However, it seems it is just an identifier for which plot of land it is. One would have to see the documentation to know for sure. In this case, the `object` dtype is appropriate.

# %%
# Print unique values of the 'Hectare' attribute
# Out:
# array(['37F', '37E', '02E', '05D', '39B', '33H', '06G', '35C', '07B',
#        '32E', '13E', '11H', '36H', '33F', '21C', '11D', '20B', '36I',
#        '05C', '07H', '16C', '14E', '32A', '17F', '16I', '12I', '32F',
#        '25A', '15E', '39G', '29I', '07E', '17C', '10A', '28A', '22F',
#        '12B', '18A', '29C', '38C', '31H', '08H', '34F', '13H', '17E',
#        '02B', '19D', '40B', '03E', '39C', '14F', '06I', '15F', '08B',
#        '03A', '05E', '05F', '11B', '16E', '13F', '29H', '23C', '33C',
#        '38G', '16G', '35A', '28C', '32D', '22A', '19C', '15G', '10F',
#        '42E', '22B', '05A', '32H', '42C', '41D', '21G', '07F', '38F',
#        '41B', '36A', '31A', '42G', '37D', '24B', '07G', '15I', '19B',
#        '13D', '35B', '40D', '38B', '40I', '40A', '03B', '21D', '10B',
#        '41A', '02F', '26A', '35E', '11G', '07A', '03D', '35D', '18G',
#        '06F', '09F', '38E', '33G', '32G', '04D', '06H', '15D', '39H',
#        '20F', '09G', '23F', '39A', '13A', '10G', '13C', '32C', '31D',
#        '18C', '40E', '04G', '12F', '17H', '03G', '15H', '14G', '42H',
#        '38A', '22C', '36F', '30D', '05I', '16D', '06D', '12E', '14D',
#        '22D', '08A', '02D', '12C', '08F', '02H', '32B', '04E', '14A',
#        '09B', '08C', '06B', '03C', '38D', '10C', '26I', '01B', '09A',
#        '37H', '06A', '32I', '04B', '31F', '23D', '30B', '04F', '33I',
#        '37C', '33B', '37I', '37G', '20A', '15A', '16F', '01G', '37B',
#        '03I', '12G', '10I', '19H', '34I', '12A', '19F', '20C', '36E',
#        '28D', '21E', '39F', '27A', '18D', '27I', '14I', '01H', '30E',
#        '16A', '11E', '22I', '41C', '29B', '15B', '18I', '12D', '11F',
#        '34D', '20D', '21F', '33D', '08E', '33E', '31G', '02C', '04I',
#        '40C', '10H', '36C', '11I', '01D', '22G', '40G', '01C', '07I',
#        '14H', '08I', '13B', '34H', '04A', '42F', '41I', '12H', '09C',
#        '36B', '31E', '21B', '29D', '42D', '19G', '13I', '24A', '36D',
#        '42B', '41E', '18F', '16H', '09D', '07D', '08G', '04C', '23E',
#        '30A', '15C', '16B', '11A', '36G', '14C', '21H', '05G', '03F',
#        '42I', '14B', '01A', '09I', '18H', '26B', '28I', '01F', '31I',
#        '17A', '03H', '02A', '30I', '09E', '39D', '34E', '17D', '21A',
#        '13G', '35F', '38I', '09H', '30C', '19E', '08D', '04H', '23B',
#        '20G', '17G', '35G', '02I', '10D', '17I', '42A', '34B', '17B',
#        '11C', '33A', '31B', '25I', '37A', '01E', '22H', '34A', '19A',
#        '06C', '07C', '05B', '23A', '02G', '35H', '06E', '41G', '40H',
#        '39I', '23I', '31C', '29A', '22E', '41F', '28B', '35I', '24I',
#        '23H', '34C', '39E', '01I', '18E', '27B', '34G', '05H', '40F',
#        '30H', '10E', '25B', '20E', '38H', '30F'], dtype=object)

# %% [markdown]
# ### Attribute values
#
# Carefully check each attribute to see if the unique values are coherent and make sense.
# Moreover, check that minimum and maximum values make sense. (e.g. age of a person that is negative)
#
# Hint: use your previously acquired knowledge of extracting unique values.
# Be careful to limit the attributes that you print by the number of unique values they have, as there are fields that have all their values that are unique, and we don't want a kilometer long list of each value.

# %%
# Print the number of unique values of each column, only printing those that have less than 100 unique values
# Out:
#  #################### Shift ####################
#
# ['PM' 'AM']
#
#  #################### Date ####################
#
# [10142018 10062018 10102018 10182018 10192018 10202018 10132018 10082018
#  10172018 10072018 10122018]
#
#  #################### Hectare Squirrel Number ####################
#
# [ 3  5  1  2  9 14 23  7  4  6 13 10 16  8 11 12 20 15 19 17 21 22 18]
#
#  #################### Age ####################
#
# [nan 'Adult' 'Juvenile' '?']
#
#  #################### Primary Fur Color ####################
#
# [nan 'Gray' 'Cinnamon' 'Black']
#
#  #################### Combination of Primary and Highlight Color ####################
#
# ['+' 'Gray+Cinnamon' 'Cinnamon+' 'Gray+' 'Cinnamon+White' 'Gray+White'
#  'Cinnamon+Gray' 'Gray+Cinnamon, White' 'Cinnamon+Gray, White'
#  'Gray+Black, Cinnamon, White' 'Black+' 'Gray+Black' 'Black+White'
#  'Black+Cinnamon' 'Gray+Black, White' 'Cinnamon+Black' 'Black+Gray'
#  'Gray+Black, Cinnamon' 'Black+Cinnamon, White' 'Cinnamon+Black, White'
#  'Black+Gray, White' 'Cinnamon+Gray, Black']
#
#  #################### Location ####################
#
# [nan 'Ground Plane' 'Above Ground']
#
#  #################### Above Ground Sighter Measurement ####################
#
# [nan 'FALSE' '4' '3' '30' '10' '6' '24' '8' '25' '5' '50' '70' '12' '2'
#  '20' '7' '13' '15' '28' '35' '100' '1' '80' '65' '40' '18' '17' '55' '60'
#  '180' '9' '45' '0' '43' '16' '33' '11' '23' '31' '14' '19']
#
#  #################### Running ####################
#
# [False  True]
#
#  #################### Chasing ####################
#
# [False  True]
#
#  #################### Climbing ####################
#
# [False  True]
#
#  #################### Eating ####################
#
# [False  True]
#
#  #################### Foraging ####################
#
# [False  True]
#
#  #################### Kuks ####################
#
# [False  True]
#
#  #################### Quaas ####################
#
# [False  True]
#
#  #################### Moans ####################
#
# [False  True]
#
#  #################### Tail flags ####################
#
# [False  True]
#
#  #################### Tail twitches ####################
#
# [False  True]
#
#  #################### Approaches ####################
#
# [False  True]
#
#  #################### Indifferent ####################
#
# [False  True]
#
#  #################### Runs from ####################
#
# [False  True]

# %%
df.describe(include='all').T # Transpose the data frame so that it fits in a cell
# Out:
#                                            count unique  \
# X                                           3023    NaN
# Y                                           3023    NaN
# Unique Squirrel ID                          3023   3018
# Hectare                                     3023    339
# Shift                                       3023      2
# Date                                        3023    NaN
# Hectare Squirrel Number                     3023    NaN
# Age                                         2902      3
# Primary Fur Color                           2968      3
# Combination of Primary and Highlight Color  3023     22
# Location                                    2959      2
# Above Ground Sighter Measurement            2909     41
# Running                                     3023      2
# Chasing                                     3023      2
# Climbing                                    3023      2
# Eating                                      3023      2
# Foraging                                    3023      2
# Kuks                                        3023      2
# Quaas                                       3023      2
# Moans                                       3023      2
# Tail flags                                  3023      2
# Tail twitches                               3023      2
# Approaches                                  3023      2
# Indifferent                                 3023      2
# Runs from                                   3023      2
# Lat/Long                                    3023   3023
#
#                                                                                    top  \
# X                                                                                  NaN
# Y                                                                                  NaN
# Unique Squirrel ID                                                       7D-PM-1010-01
# Hectare                                                                            14D
# Shift                                                                               PM
# Date                                                                               NaN
# Hectare Squirrel Number                                                            NaN
# Age                                                                              Adult
# Primary Fur Color                                                                 Gray
# Combination of Primary and Highlight Color                                       Gray+
# Location                                                                  Ground Plane
# Above Ground Sighter Measurement                                                 FALSE
# Running                                                                          False
# Chasing                                                                          False
# Climbing                                                                         False
# Eating                                                                           False
# Foraging                                                                         False
# Kuks                                                                             False
# Quaas                                                                            False
# Moans                                                                            False
# Tail flags                                                                       False
# Tail twitches                                                                    False
# Approaches                                                                       False
# Indifferent                                                                      False
# Runs from                                                                        False
# Lat/Long                                    POINT (-73.9763433202401 40.7738473490681)
#
#                                             freq         mean         std  \
# X                                            NaN     -73.9672  0.00772631
# Y                                            NaN      40.7809   0.0102853
# Unique Squirrel ID                             2          NaN         NaN
# Hectare                                       32          NaN         NaN
# Shift                                       1676          NaN         NaN
# Date                                         NaN  1.01195e+07     42466.7
# Hectare Squirrel Number                      NaN      4.12372     3.09649
# Age                                         2568          NaN         NaN
# Primary Fur Color                           2473          NaN         NaN
# Combination of Primary and Highlight Color   895          NaN         NaN
# Location                                    2116          NaN         NaN
# Above Ground Sighter Measurement            2116          NaN         NaN
# Running                                     2293          NaN         NaN
# Chasing                                     2744          NaN         NaN
# Climbing                                    2365          NaN         NaN
# Eating                                      2263          NaN         NaN
# Foraging                                    1588          NaN         NaN
# Kuks                                        2921          NaN         NaN
# Quaas                                       2973          NaN         NaN
# Moans                                       3020          NaN         NaN
# Tail flags                                  2868          NaN         NaN
# Tail twitches                               2589          NaN         NaN
# Approaches                                  2845          NaN         NaN
# Indifferent                                 1569          NaN         NaN
# Runs from                                   2345          NaN         NaN
# Lat/Long                                       1          NaN         NaN
#
#                                                    min         25%  \
# X                                             -73.9812    -73.9731
# Y                                              40.7649     40.7717
# Unique Squirrel ID                                 NaN         NaN
# Hectare                                            NaN         NaN
# Shift                                              NaN         NaN
# Date                                        1.0062e+07  1.0082e+07
# Hectare Squirrel Number                              1           2
# Age                                                NaN         NaN
# Primary Fur Color                                  NaN         NaN
# Combination of Primary and Highlight Color         NaN         NaN
# Location                                           NaN         NaN
# Above Ground Sighter Measurement                   NaN         NaN
# Running                                            NaN         NaN
# Chasing                                            NaN         NaN
# Climbing                                           NaN         NaN
# Eating                                             NaN         NaN
# Foraging                                           NaN         NaN
# Kuks                                               NaN         NaN
# Quaas                                              NaN         NaN
# Moans                                              NaN         NaN
# Tail flags                                         NaN         NaN
# Tail twitches                                      NaN         NaN
# Approaches                                         NaN         NaN
# Indifferent                                        NaN         NaN
# Runs from                                          NaN         NaN
# Lat/Long                                           NaN         NaN
#
#                                                    50%         75%         max
# X                                             -73.9686    -73.9602    -73.9497
# Y                                              40.7782     40.7912     40.8001
# Unique Squirrel ID                                 NaN         NaN         NaN
# Hectare                                            NaN         NaN         NaN
# Shift                                              NaN         NaN         NaN
# Date                                        1.0122e+07  1.0142e+07  1.0202e+07
# Hectare Squirrel Number                              3           6          23
# Age                                                NaN         NaN         NaN
# Primary Fur Color                                  NaN         NaN         NaN
# Combination of Primary and Highlight Color         NaN         NaN         NaN
# Location                                           NaN         NaN         NaN
# Above Ground Sighter Measurement                   NaN         NaN         NaN
# Running                                            NaN         NaN         NaN
# Chasing                                            NaN         NaN         NaN
# Climbing                                           NaN         NaN         NaN
# Eating                                             NaN         NaN         NaN
# Foraging                                           NaN         NaN         NaN
# Kuks                                               NaN         NaN         NaN
# Quaas                                              NaN         NaN         NaN
# Moans                                              NaN         NaN         NaN
# Tail flags                                         NaN         NaN         NaN
# Tail twitches                                      NaN         NaN         NaN
# Approaches                                         NaN         NaN         NaN
# Indifferent                                        NaN         NaN         NaN
# Runs from                                          NaN         NaN         NaN
# Lat/Long                                           NaN         NaN         NaN

# %% [markdown]
# **Does something stand out to you ?**
#
# In the column `Combination of Primary and Highlight Color` for example, we have a value that is only `'+'`.
# Again, there are multiple ways to deal with this. When you can't figure out what the value means (like in this case), you can drop it. Sometimes, when you are able to figure out which one is meant, you can replace it with the correct value. This is where the domain knowledge come into play, knowing which variable can be replaced with what, and what it could mean.

# %% [markdown]
# Another example, from another dataset containing vehicle types where the vehicle type was manually encoded.
# You see how 'Tow truck' appears in many different forms.
# The right approach is to consolidate all of the different values of tow truck into a single one.

# %%
trucks = ['Pick-up Truck', 'Tractor Truck Diesel', 'Box Truck', 'Tractor Truck Gasoline', 'Tow Truck / Wrecker', 'Beverage Truck', 'truck', 'Armored Truck', 'TRUCK', 'Truck', 'Tow Truck', 'FIRE TRUCK', 'PICK-UP TRUCK', 'BOX TRUCK', 'Fire Truck', 'box truck', 'TRUCK FLAT', 'FIRTRUCK', 'TRUCK VAN', 'FIRETRUCK', 'FDNY TRUCK', 'dump truck', 'Fire truck', 'UPS TRUCK', 'fire truck', 'FOOD TRUCK', 'MAIL TRUCK', 'USPS TRUCK', 'tow truck', 'TOW TRUCK', 'Tow truck']
[truck for truck in trucks if 'tow' in truck.lower()]
# Out:
# ['Tow Truck / Wrecker', 'Tow Truck', 'tow truck', 'TOW TRUCK', 'Tow truck']

# %% [markdown]
# ### Duplicates
#
# Search for duplicates and remove them

# %%
# There are no duplicates
df.duplicated().any()
# Out:
# False

# %% [markdown]
# If there had been, call `df.drop_duplicates(inplace=True)` to remove them.
#
# Again, this is just a short introduction to data cleaning of structured data, there are many more steps that one could optionally take.

# %% [markdown]
# ## References and reading material
#
# [Data cleaning challenge - Kaggle](https://www.kaggle.com/rtatman/data-cleaning-challenge-handling-missing-values)
# [Preparing data for a machine learning model - Dataquest](https://www.dataquest.io/blog/machine-learning-preparing-data/)
# [Preliminary data cleaning - Kaggle](https://www.kaggle.com/quannguyen135/preliminary-data-cleaning-with-python)
# [Pandas data cleaning cheatsheet - Elite Data Science](https://elitedatascience.com/python-cheat-sheet)
